# %% [markdown]
# <a href="https://colab.research.google.com/github/darenjabrica/DSA-58010/blob/main/DSA_Group1_WonderPets_FinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# list to store the customer orders
customerQueue = []

# take customer order
def take_order(customer_name, order):
  # append customer order to the queue
  customerQueue.append((customer_name, order))
  print(f"===================================================\n\n(QUEUE HAS BEEN UPDATED)\nOrder added to queue: {customer_name} - {order}\n")

# show the customer queue
def show_queue():
  # current queue
  print("===================================================\n(DISPLAY QUEUE)\n\nCurrently In Line: \n")
  for i, (customer_name, order) in enumerate(customerQueue):
    print(f"{i + 1}. {customer_name} - {order}")

# pop customer from queue
def pop_queue():
  # cehck queue if empty
  if len(customerQueue) == 0:
    print(f"===================================================\n\n(OOOPS)\nQueue is currently empty!\n")
    return
  # Pop current customer from the queue 
  (customer_name, order) = customerQueue.pop(0)
  print(f"===================================================\n\n(ORDER READY)\n\nYour Order is ready: {customer_name} - {order}\n")

# Prompt the user
while True:
  # Menu options
  print("===================================================\n (MENU) What would you like to do?\n")
  print("1. Take an order")
  print("2. Show queue")
  print("3. Serve queue")
  print("4. Quit")

  # user's input
  resp = input("\nPlease Respond:")
  if resp == "1":
    # Prompt the user for the customer name and order
    customer_name = input("===================================================\n(TAKE CUSTOMER'S ORDER)\n\nYou are now taking an order!\nPlease Enter Customer name: ")
    order = input("Enter Customer order: ")
    take_order(customer_name, order)
  elif resp == "2":
    show_queue()
  elif resp == "3":
    pop_queue()
  elif resp == "4":
    break
  else:
    print("===================================================\n\nInvalid Input\nPlease Try Again :>\n")
# Out:
# ===================================================
#  (MENU) What would you like to do?
#
# 1. Take an order
# 2. Show queue
# 3. Serve queue
# 4. Quit
#
# Please Respond:1
# ===================================================
# (TAKE CUSTOMER'S ORDER)
#
# You are now taking an order!
# Please Enter Customer name: Neil
# Enter Customer order: Chicken
# ===================================================
#
# (QUEUE HAS BEEN UPDATED)
# Order added to queue: Neil - Chicken
#
# ===================================================
#  (MENU) What would you like to do?
#
# 1. Take an order
# 2. Show queue
# 3. Serve queue
# 4. Quit
#
# Please Respond:1
# ===================================================
# (TAKE CUSTOMER'S ORDER)
#
# You are now taking an order!
# Please Enter Customer name: Daren
# Enter Customer order: Fries
# ===================================================
#
# (QUEUE HAS BEEN UPDATED)
# Order added to queue: Daren - Fries
#
# ===================================================
#  (MENU) What would you like to do?
#
# 1. Take an order
# 2. Show queue
# 3. Serve queue
# 4. Quit
#
# Please Respond:1
# ===================================================
# (TAKE CUSTOMER'S ORDER)
#
# You are now taking an order!
# Please Enter Customer name: Nabi
# Enter Customer order: Jolly Hotdog
# ===================================================
#
# (QUEUE HAS BEEN UPDATED)
# Order added to queue: Nabi - Jolly Hotdog
#
# ===================================================
#  (MENU) What would you like to do?
#
# 1. Take an order
# 2. Show queue
# 3. Serve queue
# 4. Quit
#
# Please Respond:1
# ===================================================
# (TAKE CUSTOMER'S ORDER)
#
# You are now taking an order!
# Please Enter Customer name: Daniel
# Enter Customer order: shawarma
# ===================================================
#
# (QUEUE HAS BEEN UPDATED)
# Order added to queue: Daniel - shawarma
#
# ===================================================
#  (MENU) What would you like to do?
#
# 1. Take an order
# 2. Show queue
# 3. Serve queue
# 4. Quit
#
# Please Respond:1
# ===================================================
# (TAKE CUSTOMER'S ORDER)
#
# You are now taking an order!
# Please Enter Customer name: Conrad
# Enter Customer order: Sisig
# ===================================================
#
# (QUEUE HAS BEEN UPDATED)
# Order added to queue: Conrad - Sisig
#
# ===================================================
#  (MENU) What would you like to do?
#
# 1. Take an order
# 2. Show queue
# 3. Serve queue
# 4. Quit
#
# Please Respond:2
# ===================================================
# (DISPLAY QUEUE)
#
# Currently In Line:
#
# 1. Neil - Chicken
# 2. Daren - Fries
# 3. Nabi - Jolly Hotdog
# 4. Daniel - shawarma
# 5. Conrad - Sisig
# ===================================================
#  (MENU) What would you like to do?
#
# 1. Take an order
# 2. Show queue
# 3. Serve queue
# 4. Quit
#
# Please Respond:3
# ===================================================
#
# (ORDER READY)
#
# Your Order is ready: Neil - Chicken
#
# ===================================================
#  (MENU) What would you like to do?
#
# 1. Take an order
# 2. Show queue
# 3. Serve queue
# 4. Quit
#
# Please Respond:2
# ===================================================
# (DISPLAY QUEUE)
#
# Currently In Line:
#
# 1. Daren - Fries
# 2. Nabi - Jolly Hotdog
# 3. Daniel - shawarma
# 4. Conrad - Sisig
# ===================================================
#  (MENU) What would you like to do?
#
# 1. Take an order
# 2. Show queue
# 3. Serve queue
# 4. Quit
#
# Please Respond:4
